# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
from weather_file_builder import visualization
from weather_file_builder import utils

# %%
root_dir = "/Users/jmccarty/Desktop/test_tmy_builder/magnitogorsk"
tmy_file = os.path.join(root_dir, "tmy.csv")
timeseries_file = os.path.join(root_dir, "timeseries.csv")
tmy_df = pd.read_csv(tmy_file)
timeseries_df = pd.read_csv(timeseries_file)

# %%
selected_years = utils.extract_selected_years(tmy_df)

# %%
fig = visualization.create_tmy_plot(
    timeseries_df,
    tmy_df,
    selected_years
)
# Out:
# Using latitude from data: 53.4200
# Using longitude from data: 58.9400
# Creating TMY visualization with 7 selected years: [np.int64(1993), np.int64(1994), np.int64(1996), np.int64(1999), np.int64(2000), np.int64(2002), np.int64(2010)]
# Creating TMY visualization with 7 years...
# TMY visualization complete!

# %%
fig
# Out:
#        Year  Month  Day  Hour  Minute  Latitude  Longitude  Temperature  \
# 8760   1994      1    1     0       0     53.42      58.94    -29.88322
# 8761   1994      1    1     1       0     53.42      58.94    -29.94613
# 8762   1994      1    1     2       0     53.42      58.94    -30.04545
# 8763   1994      1    1     3       0     53.42      58.94    -30.09970
# 8764   1994      1    1     4       0     53.42      58.94    -30.08889
# ...     ...    ...  ...   ...     ...       ...        ...          ...
# 17515  1994     12   31    19       0     53.42      58.94     -2.67353
# 17516  1994     12   31    20       0     53.42      58.94     -2.50028
# 17517  1994     12   31    21       0     53.42      58.94     -2.30826
# 17518  1994     12   31    22       0     53.42      58.94     -2.26250
# 17519  1994     12   31    23       0     53.42      58.94     -2.09060
#
#        Dew Point   Pressure  Relative Humidity  Wind Speed  Wind Direction  \
# ...
